# %%
import requests

# %%
url = 'https://www.linkedin.com/jobs/search/?currentJobId=3518208047&distance=25&geoId=100994331&keywords=data%20analyst'

# %%
lkdin = requests.get(url)

# %%
lkdin.status_code
# Out:
# 200

# %%
print(lkdin.text)
# Out:
# <!DOCTYPE html>
#
#
#
#
#
#
#
#
#     <html lang="en">
#       <head>
#         <meta name="pageKey" content="d_jobs_guest_search">
#           <meta name="linkedin:pageTag" content="urlType=jserp_custom;emptyResult=false">
#         <meta name="locale" content="en_US">
#         <meta id="config" data-app-version="2.0.1300" data-call-tree-id="AAX8CqZsNP0FqWxKSViVjw==" data-multiproduct-name="jobs-guest-frontend" data-service-name="jobs-guest-frontend" data-browser-id="3e4f74a6-f0f0-496e-8919-e992f4c8573c" data-enable-page-view-heartbeat-tracking data-page-instance="urn:li:page:d_jobs_guest_search;r5oCD1CBQlmcXzHQ6gKaJw==" data-disable-jsbeacon-pagekey-suffix="false" data-member-id="0">
#
#         <link rel="canonical" href="https://es.linkedin.com/jobs/data-analyst-empleos-madrid">
# <!----><!---->
# <!---->
# <!---->
# <!---->
# <!---->
#           <link rel="icon" href="https://static.licdn.com/aero-v1/sc/h/al2o9zrvru7aqj8e1x2rzsrca">
#
#         <script>
# ...

# %%
lkdin.request.headers
# Out:
# {'User-Agent': 'python-requests/2.29.0', 'Accept-Encoding': 'gzip, deflate, br', 'Accept': '*/*', 'Connection': 'keep-alive'}

# %%
from bs4 import BeautifulSoup

# %%
soup = BeautifulSoup(lkdin.text, 'lxml')

# %%
print(soup.prettify())
# Out:
# <!DOCTYPE html>
# <html lang="en">
#  <head>
#   <meta content="d_jobs_guest_search" name="pageKey"/>
#   <meta content="urlType=jserp_custom;emptyResult=false" name="linkedin:pageTag"/>
#   <meta content="en_US" name="locale"/>
#   <meta data-app-version="2.0.1300" data-browser-id="3e4f74a6-f0f0-496e-8919-e992f4c8573c" data-call-tree-id="AAX8CqZsNP0FqWxKSViVjw==" data-disable-jsbeacon-pagekey-suffix="false" data-enable-page-view-heartbeat-tracking="" data-member-id="0" data-multiproduct-name="jobs-guest-frontend" data-page-instance="urn:li:page:d_jobs_guest_search;r5oCD1CBQlmcXzHQ6gKaJw==" data-service-name="jobs-guest-frontend" id="config"/>
#   <link href="https://es.linkedin.com/jobs/data-analyst-empleos-madrid" rel="canonical"/>
#   <!-- -->
#   <!-- -->
#   <!-- -->
#   <!-- -->
#   <!-- -->
#   <!-- -->
#   <link href="https://static.licdn.com/aero-v1/sc/h/al2o9zrvru7aqj8e1x2rzsrca" rel="icon"/>
#   <script>
# ...

# %%
# print(soup.find_all('a', attrs={'class': 'disabled ember-view job-card-container__link job-card-list__title'}))
# Out:
# []

# %%
soup.find('a', class_= 'disabled ember-view job-card-container__link job-card-list__title')
